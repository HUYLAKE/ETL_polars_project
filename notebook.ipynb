# %%
import polars as pl
import connectorx
from config import mysql_pass

# %%
uri = f'mysql://root:{mysql_pass}@localhost:3306/analytics'

# %%
query = 'SELECT * FROM analytics.dim_customer;'

# %%
df = pl.read_database_uri(query, uri)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\GIA LAC\Desktop\data_project\venv\Lib\site-packages\connectorx\__init__.py:553, in try_import_module(name)
#     552 try:
# --> 553     return importlib.import_module(name)
#     554 except ModuleNotFoundError:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'pyarrow'
#
# ...
